# %% [markdown]
# <a href="https://colab.research.google.com/github/endy24ti-commits/Probabilitas_Statistika_Endy3TID/blob/main/Probabilitas_%26_Statistika_Endy_3_TID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataraw = pd.read_excel('Endy.xlsx')
dataraw.style.background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_91e02_row0_col0, #T_91e02_row9_col3, #T_91e02_row20_col2, #T_91e02_row20_col4, #T_91e02_row20_col5 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_91e02_row0_col2 {
#   background-color: #11753d;
#   color: #f1f1f1;
# }
# #T_91e02_row0_col3 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_91e02_row0_col4, #T_91e02_row11_col4 {
#   background-color: #006536;
#   color: #f1f1f1;
# }
# #T_91e02_row0_col5 {
#   background-color: #15793e;
#   color: #f1f1f1;
# }
# #T_91e02_row1_col0 {
#   background-color: #fcfed7;
#   color: #000000;
# }
# #T_91e02_row1_col2, #T_91e02_row1_col5, #T_91e02_row18_col2, #T_91e02_row18_col4 {
#   background-color: #00542f;
#   color: #f1f1f1;
# }
# #T_91e02_row1_col3, #T_91e02_row18_col3 {
#   background-color: #076d39;
#   color: #f1f1f1;
# }
# #T_91e02_row1_col4 {
#   background-color: #004f2d;
#   color: #f1f1f1;
# }
# #T_91e02_row2_col0 {
#   background-color: #eef9b3;
#   color: #000000;
# }
# ...

# %%
#Tabel Frekuensi
datafrq = pd.crosstab(index=dataraw['Grade'], columns='Frekuensi')
print(datafrq)
# Out:
# col_0  Frekuensi
# Grade
# A             12
# AB             7
# B              4
# BC             1
# C              5
# F              1

# %%
datafrq.plot(color='yellow')
# Out:
# <Axes: xlabel='Grade'>

# %%
warna = ['red', 'blue', 'green', 'orange', 'purple', 'cyan']
plt.bar(datafrq.index, datafrq['Frekuensi'], color=warna)
plt.xlabel('Grade')
plt.ylabel('Frekuensi')
plt.show()

# %%
warna_terang = ['#FF0000', '#0000FF', '#00FF00', '#FF8000', '#8000FF', '#00FFFF']
datafrq.plot(kind='pie', y='Frekuensi', autopct='%1.0f%%', legend=False, colors=warna_terang)
# Out:
# <Axes: ylabel='Frekuensi'>

# %%
#Statistika Deskriptif
dataraw["Final Score"] = pd.to_numeric(dataraw["Final Score"],errors='coerce')
dt = dataraw["Final Score"]
stats = dt.describe()
stats['Standard Error'] = dt.sem()
stats['Median'] = dt.median()
stats['Mode'] = dt.mode().iloc[0]
stats['Variance'] = dt.var()
stats['Range'] = dt.max() - dt.min()
stats['Skewness'] = dt.skew()
stats['Kurtosis'] = dt.kurtosis()
print(stats)
# Out:
# count              30.000000
# mean               76.233333
# std                13.477994
# min                46.000000
# 25%                68.083333
# 50%                78.833333
# 75%                87.083333
# max                94.000000
# Standard Error      2.460734
# Median             78.833333
# Mode               77.333333
# Variance          181.656322
# Range              48.000000
# Skewness           -0.672946
# Kurtosis           -0.513549
# Name: Final Score, dtype: float64
